# %%
import numpy as np
import matplotlib.pyplot as plt
import collections
import import_ipynb
from e2elatency import graph,label
from topic import cb,cbd,ps_com,node_com

# %%
# callback of node
path = '/home/rei/reigit/avpdemo.txt'
f = open(path)
f.close()
with open(path) as f:
    l = f.readlines()
    
S = l.index('Nodes:\n')
E = l.index('Publishers:\n')
no=[]
for i in l[S+3:E-1]:
    no.append(i.split()[4])
print(no)
node=['filter_transform_vlp16_front','filter_transform_vlp16_rear','point_cloud_fusion_nodes','voxel_grid_cloud_node','p2d_ndt_localizer_n',
      'lanelet2_global_planner_node',
      'ray_ground_classifier','euclidean_cluster_cloud_node','off_map_obstacles_filter_node',
      'object_collision_estimator_node','behavior_planner_node','mpc_controller_node',
      'ndt_map_publisher_node','lanelet2_map_visualizer_node','lanelet2_map_provider_node','parking_planner_node']
for i in node:
    print(i)
    cb(i)
    print('\n')
# Out:
# ['bridge', 'robot_state_publisher', 'lgsvl_interface_node', 'transform_listener_impl_55b98c816140', 'ndt_map_publisher_node', 'p2d_ndt_localizer_node', 'mpc_controller_node', 'filter_transform_vlp16_front', 'euclidean_cluster_cloud_node', 'lanelet2_global_planner_node', 'ray_ground_classifier', 'lanelet2_map_provider_node', 'off_map_obstacles_filter_node', 'point_cloud_fusion_nodes', 'lanelet2_map_visualizer_node', 'lane_planner_node', 'filter_transform_vlp16_rear', 'behavior_planner_node', 'parking_planner_node', 'voxel_grid_cloud_node', 'object_collision_estimator_node', 'transform_listener_impl_55d85bb31530', 'transform_listener_impl_56475af99a70', 'rviz2', 'rosbridge_server_node', 'transform_listener_impl_561ebe6eab90', 'transform_listener_impl_561ebe776630']
# filter_transform_vlp16_front
# sub: ['/parameter_events', '/lidar_front/points_raw']
# pub: ['/rosout', '/parameter_events', '/lidar_front/points_filtered']
# ...

# %%
# callback duration of node: node name,topic name
node='filter_transform_vlp16_front'
topic='/lidar_front/points_raw'
cbduration,title = cbd(node,topic)
graph(cbduration,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])
# com latency
comlatency,title=ps_com(node,topic)
graph(comlatency,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])

# callback duration of node: node name,topic name
node='filter_transform_vlp16_rear'
topic='/lidar_rear/points_raw'
cbduration,title = cbd(node,topic)
graph(cbduration,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])
# com latency
comlatency,title=ps_com(node,topic)
graph(comlatency,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])

# callback duration of node: node name,topic name
node='lanelet2_global_planner_node'
topic='/planning/goal_pose'
cbduration,title = cbd(node,topic)
graph(cbduration,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])
# com latency
comlatency,title=ps_com(node,topic)
graph(comlatency,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])

# callback duration of node: node name,topic name
node='lanelet2_global_planner_node'
topic='/vehicle/vehicle_kinematic_state'
cbduration,title = cbd(node,topic)
graph(cbduration,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])
# com latency
comlatency,title=ps_com(node,topic)
graph(comlatency,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])

# callback duration of node: node name,topic name
node='ray_ground_classifier'
topic='/lidars/points_fused'
cbduration,title = cbd(node,topic)
graph(cbduration,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])
# com latency
comlatency,title=ps_com(node,topic)
graph(comlatency,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])

# callback duration of node: node name,topic name
node='euclidean_cluster_cloud_node'
topic='/perception/points_nonground'
cbduration,title = cbd(node,topic)
graph(cbduration,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])
# com latency
comlatency,title=ps_com(node,topic)
graph(comlatency,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])

# callback duration of node: node name,topic name
node='off_map_obstacles_filter_node'
topic='/perception/lidar_bounding_boxes'
cbduration,title = cbd(node,topic)
graph(cbduration,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])
# com latency
comlatency,title=ps_com(node,topic)
graph(comlatency,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])

# callback duration of node: node name,topic name
node='object_collision_estimator_node'
topic='/perception/lidar_bounding_boxes_filtered'
cbduration,title = cbd(node,topic)
graph(cbduration,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])
# com latency
comlatency,title=ps_com(node,topic)
graph(comlatency,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])

# %%
# callback duration of node: node name,topic name
node='behavior_planner_node'
topic='/vehicle/vehicle_kinematic_state'
cbduration,title = cbd(node,topic)
graph(cbduration,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])
# com latency
comlatency,title=ps_com(node,topic)
graph(comlatency,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])

# callback duration of node: node name,topic name
node='behavior_planner_node'
topic='/planning/global_path'
cbduration,title = cbd(node,topic)
graph(cbduration,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])
# com latency
comlatency,title=ps_com(node,topic)
graph(comlatency,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])

# callback duration of node: node name,topic name
node='mpc_controller_node'
topic='/planning/trajectory'
cbduration,title = cbd(node,topic)
graph(cbduration,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])
# com latency
comlatency,title=ps_com(node,topic)
graph(comlatency,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])

# %%
# # callback duration of node: node name,topic name
# node='point_cloud_fusion_nodes'
# topic='/lidar_front/points_filtered'
# cbduration,title = cbd(node,topic)
# graph(cbduration,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])
# # com latency
# comlatency,title=ps_com(node,topic)
# graph(comlatency,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])

# # callback duration of node: node name,topic name
# node='point_cloud_fusion_nodes'
# topic='/lidar_rear/points_filtered'
# cbduration,title = cbd(node,topic)
# graph(cbduration,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])
# # com latency
# comlatency,title=ps_com(node,topic)
# graph(comlatency,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])

# %%
# callback duration of node: node name,topic name
node='p2d_ndt_localizer_n'
topic='/lidars/points_fused_downsampled'
cbduration,title = cbd(node,topic)
graph(cbduration,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])
# com latency
comlatency,title=ps_com(node,topic)
graph(comlatency,title+': '+topic.split('/')[1]+'-'+topic.split('/')[2])

# %%
# callback duration of node: node name,topic name
node='behavior_planner_node'
topic='/tf'
cbduration,title = cbd(node,topic)
graph(cbduration,title+': '+topic.split('/')[1])
# com latency
comlatency,title=ps_com(node,topic)
graph(comlatency,title+': '+topic.split('/')[1])
